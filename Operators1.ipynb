# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinash6767/Python_Basics/blob/main/Operators1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'X' in [1,2,3]
# Out:
# True

# %%
'X' in ['X', 2, 'Y']
# Out:
# True

# %%
'X' not in ['X', 'Y', 'Z']
# Out:
# False

# %%
'X' not in [1,2,3]
# Out:
# True

# %%
myList = [12,1,31,2,3,1,2,3,2,3,3,54,3,4,5,4,3,-22]

min(myList)
# Out:
# -22

# %%
max(myList)
# Out:
# 54

# %% [markdown]
# **Random**
#
# Python comes with a built in random library. There are lot of functions included in this library.

# %%
from random import shuffle

# %%
shuffle(myList)

# %%
myList
# Out:
# [4, 1, 4, 2, 31, 3, 3, 1, 2, 12, 54, 3, -22, 3, 3, 5, 2, 3]

# %%
from random import randint

# %%
randint(9, 14)
# Out:
# 14

# %%
number = []
for _ in range(7):
  number.append(randint(100, 200))
print(number)
# Out:
# [104, 118, 165, 180, 192, 198, 121]
